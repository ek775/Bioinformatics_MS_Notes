# %% [markdown]
# # Variant Analysis
# Assigned Profile:
# https://my.pgp-hms.org/profile/hu1A8C1E
#
# 43y - Female

# %%
import pandas as pd

# %%
df = pd.read_csv('results.tsv', delimiter='\t')
df
# Out:
# C:\Users\ninja\AppData\Local\Temp\ipykernel_6256\4060710496.py:1: DtypeWarning: Columns (1,12,17,31,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('results.tsv', delimiter='\t')
#         # inDBSNPOrNot chromosome  position referenceBase sampleGenotype  \
# 0                 none          1    799082             G              A
# 1           dbSNP_2002          1    817341             A              R
# 2           dbSNP_2004          1    841166             A              R
# 3           dbSNP_2004          1    841166             A              R
# 4           dbSNP_2004          1    841166             A              R
# ...                ...        ...       ...           ...            ...
# 1232324           none          Y  57187205             T              Y
# 1232325           none          Y  57187205             T              Y
# 1232326           none          Y  57187205             T              Y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232329 entries, 0 to 1232328
# Data columns (total 34 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   # inDBSNPOrNot       1232329 non-null  object
#  1   chromosome           1232329 non-null  object
#  2   position             1232329 non-null  int64
#  3   referenceBase        1232329 non-null  object
#  4   sampleGenotype       1232329 non-null  object
#  5   sampleAlleles        1232329 non-null  object
#  6   allelesDBSNP         1232329 non-null  object
#  7   accession            1232329 non-null  object
#  8   functionGVS          1232329 non-null  object
#  9   functionDBSNP        1232329 non-null  object
#  10  rsID                 1232329 non-null  int64
#  11  aminoAcids           1232329 non-null  object
#  12  proteinPosition      34573 non-null    object
#  13  cDNAPosition         38770 non-null    float64
# ...

# %%
df["# inDBSNPOrNot"].unique()
# Out:
# array(['none', 'dbSNP_2002', 'dbSNP_2004', 'dbSNP_2000', 'dbSNP_2009',
#        'dbSNP_2003', 'dbSNP_2001', 'dbSNP_2008', 'dbSNP_2006',
#        'dbSNP_2010', 'dbSNP_2005', 'dbSNP_2011', 'dbSNP_2007',
#        'dbSNP_1999', 'dbSNP_2012'], dtype=object)

# %%
df = df[df["# inDBSNPOrNot"] != 'none']
df
# Out:
#         # inDBSNPOrNot chromosome  position referenceBase sampleGenotype  \
# 1           dbSNP_2002          1    817341             A              R
# 2           dbSNP_2004          1    841166             A              R
# 3           dbSNP_2004          1    841166             A              R
# 4           dbSNP_2004          1    841166             A              R
# 5           dbSNP_2004          1    841166             A              R
# ...                ...        ...       ...           ...            ...
# 1232307     dbSNP_2001          Y  57056752             C              T
# 1232308     dbSNP_2001          Y  57057008             T              C
# 1232309     dbSNP_2003          Y  57152755             A              G
# 1232310     dbSNP_2001          Y  57187205             T              Y
# 1232311     dbSNP_2001          Y  57187205             T              Y
#
#         sampleAlleles allelesDBSNP        accession    functionGVS  \
# ...

# %%
df["accession"].unique()
# Out:
# array(['none', 'NR_047519.1', 'NR_047521.1', ..., 'NM_005840.2.dup',
#        'NM_002186.3.dup', 'NM_176786.2.dup'], dtype=object)

# %%
df = df[df["accession"] != 'none']
df
# Out:
#         # inDBSNPOrNot chromosome  position referenceBase sampleGenotype  \
# 2           dbSNP_2004          1    841166             A              R
# 3           dbSNP_2004          1    841166             A              R
# 4           dbSNP_2004          1    841166             A              R
# 5           dbSNP_2004          1    841166             A              R
# 6           dbSNP_2004          1    841166             A              R
# ...                ...        ...       ...           ...            ...
# 1232296     dbSNP_2000          Y  56966519             A              C
# 1232297     dbSNP_2000          Y  56966714             T              C
# 1232298     dbSNP_2000          Y  56968190             T              Y
# 1232310     dbSNP_2001          Y  57187205             T              Y
# 1232311     dbSNP_2001          Y  57187205             T              Y
#
#         sampleAlleles allelesDBSNP        accession  functionGVS  \
# ...

# %%
df["functionGVS"].unique()
# Out:
# array(['intron', 'intron-near-splice', '5-prime-UTR', 'synonymous',
#        'missense', '3-prime-UTR', 'non-coding-exon', 'splice-acceptor',
#        'splice-donor', 'stop-gained', 'synonymous-near-splice',
#        'missense-near-splice', 'non-coding-exon-near-splice', 'stop-lost'],
#       dtype=object)

# %%
df["functionDBSNP"].unique()
# Out:
# array(['intron_variant', '5_prime_UTR_variant',
#        'missense_variant,synonymous_variant', 'missense_variant',
#        'synonymous_variant', '3_prime_UTR_variant',
#        'non_coding_transcript_variant', 'splice_acceptor_variant',
#        'coding_sequence_variant', 'splice_donor_variant',
#        'missense_variant,stop_gained', 'stop_gained,synonymous_variant',
#        'coding_sequence_variant,missense_variant',
#        'missense_variant,stop_gained,synonymous_variant',
#        'coding_sequence_variant,stop_gained,synonymous_variant',
#        'coding_sequence_variant,synonymous_variant', 'stop_gained',
#        'stop_lost', 'coding_sequence_variant,stop_gained',
#        'coding_sequence_variant,missense_variant,synonymous_variant',
#        'stop_lost,synonymous_variant'], dtype=object)

# %%
import re
df = df[df["functionDBSNP"] == "coding_sequence_variant"]
df["functionDBSNP"].unique()
# Out:
# array(['coding_sequence_variant'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 580 entries, 4525 to 1225131
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   # inDBSNPOrNot       580 non-null    object
#  1   chromosome           580 non-null    object
#  2   position             580 non-null    int64
#  3   referenceBase        580 non-null    object
#  4   sampleGenotype       580 non-null    object
#  5   sampleAlleles        580 non-null    object
#  6   allelesDBSNP         580 non-null    object
#  7   accession            580 non-null    object
#  8   functionGVS          580 non-null    object
#  9   functionDBSNP        580 non-null    object
#  10  rsID                 580 non-null    int64
#  11  aminoAcids           580 non-null    object
#  12  proteinPosition      580 non-null    object
#  13  cDNAPosition         580 non-null    float64
#  14  polyPhen             580 non-null    object
# ...

# %%
df = df.sort_values('granthamScore', axis=0, ascending=False)
df['granthamScore'][:30]
# Out:
# 329822     205.0
# 329823     205.0
# 329824     205.0
# 329817     205.0
# 329818     205.0
# 329816     205.0
# 329820     205.0
# 329821     205.0
# 329819     205.0
# 501287     194.0
# 17045      194.0
# 872643     194.0
# 501286     194.0
# 1221068    194.0
# 1221067    194.0
# 872641     155.0
# 307890     152.0
# 182273     145.0
# 134244     145.0
# 134245     145.0
# 663108     145.0
# 182275     145.0
# 182274     145.0
# 663107     145.0
# 182272     145.0
# 182271     145.0
# 81360      145.0
# 182270     145.0
# 134243     145.0
# 663106     145.0
# Name: granthamScore, dtype: float64

# %%
df
# Out:
#         # inDBSNPOrNot chromosome   position referenceBase sampleGenotype  \
# 329822      dbSNP_2001          4  103043372             A              M
# 329823      dbSNP_2001          4  103043372             A              M
# 329824      dbSNP_2001          4  103043372             A              M
# 329817      dbSNP_2001          4  103043372             A              M
# 329818      dbSNP_2001          4  103043372             A              M
# ...                ...        ...        ...           ...            ...
# 1153087     dbSNP_2001         19   55651410             C              T
# 1153088     dbSNP_2001         19   55651410             C              T
# 1209206     dbSNP_2003         22   49997051             A              G
# 1221073     dbSNP_2003          X   35803010             C              T
# 1221074     dbSNP_2003          X   35803010             C              T
#
#         sampleAlleles allelesDBSNP       accession  functionGVS  \
# ...
